# %%
import csv

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])

inventory = Inventory('laptops.csv')
print(inventory.header)
print(len(inventory.rows))
# Out:
# ['Id', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']
# 1303

# %%
import csv

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None

inventory = Inventory('laptops.csv')
print(inventory.header)
print(inventory.get_laptop_from_id('3362737'))
print(inventory.get_laptop_from_id('3362736'))
# Out:
# ['Id', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']
# ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 575]
# None

# %%
import csv

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None

inventory = Inventory('laptops.csv')
print(inventory.get_laptop_from_id('3362737'))
print(inventory.get_laptop_from_id('3362736'))
# Out:
# ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 575]
# None

# %%
import csv
import time
import random

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
ids = [str(random.randint(1000000,9999999)) for _ in range(10000)]

inventory = Inventory('laptops.csv')

total_time_no_dict = 0
for identifier in ids:
    start = time.time()
    inventory.get_laptop_from_id(identifier)
    end = time.time()
    total_time_no_dict += end - start
    
total_time_dict = 0
for identifier in ids:
    start = time.time()
    inventory.get_laptop_from_id_fast(identifier)
    end = time.time()
    total_time_dict += end - start

print(total_time_no_dict)                                           # step 9
print(total_time_dict)
# Out:
# 2.2094974517822266
# 0.006235361099243164

# %%
import csv
import time
import random

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
            for rowi in self.rows:
                for rowj in self.rows:
                    if rowi[-1] + rowj[-1] == dollars:
                        return True
            return False

inventory = Inventory('laptops.csv')
print(inventory.check_promotion_dollars(1000))
print(inventory.check_promotion_dollars(442))
# Out:
# True
# False

# %%
import csv
import time
import random

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
        self.prices = set()
        for row in self.rows:
            self.prices.add(row[-1])
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
            for rowi in self.rows:
                for rowj in self.rows:
                    if rowi[-1] + rowj[-1] == dollars:
                        return True
            return False
    def check_promotion_dollars_fast(self, dollars):
        if dollars in self.prices:
            return True
        for price in self.prices:
            if dollars - price in self.prices:
                return True
        return False

inventory = Inventory('laptops.csv')
print(inventory.check_promotion_dollars_fast(1000))
print(inventory.check_promotion_dollars_fast(442))
# Out:
# True
# False

# %%
import csv
import time
import random

class Inventory():

    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = int(row[-1])
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
        self.prices = set()
        for row in self.rows:
            self.prices.add(row[-1])
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
            for rowi in self.rows:
                for rowj in self.rows:
                    if rowi[-1] + rowj[-1] == dollars:
                        return True
            return False
    def check_promotion_dollars_fast(self, dollars):
        if dollars in self.prices:
            return True
        for price in self.prices:
            if dollars - price in self.prices:
                return True
        return False

prices = [random.randint(100,5000) for _ in range(100)]

inventory = Inventory('laptops.csv')

total_time_no_set = 0
for value in prices:
    start = time.time()
    inventory.check_promotion_dollars(value)
    end = time.time()
    total_time_no_set += end - start
    
total_time_set = 0
for value in prices:
    start = time.time()
    inventory.check_promotion_dollars_fast(value)
    end = time.time()
    total_time_set += end - start

print(total_time_no_set)  
print(total_time_set)
# Out:
# 3.721118450164795
# 0.0007174015045166016

# %%
import csv
import time
import random

# Função para extrair o preço de uma linha (usada para ordenar a lista de laptops)
def row_price(row):
    return row[-1]

class Inventory():

    # Inicialização da classe Inventory com base no arquivo CSV fornecido
    def __init__(self, csv_filename):
        with open(csv_filename, 'r') as f:
            reader = csv.reader(f)
            rows = list(reader)
        
        # Armazena o cabeçalho e as linhas do CSV
        self.header = rows[0]
        self.rows = rows[1:]
        
        # Converte os preços das linhas para números inteiros
        for row in self.rows:
            row[-1] = int(row[-1])
        
        # Cria um mapeamento de ID para linha para acesso rápido
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
        
        # Cria um conjunto de preços únicos
        self.prices = set()
        for row in self.rows:
            self.prices.add(row[-1])
        
        # Ordena as linhas por preço
        self.rows_by_price = sorted(self.rows, key=row_price)
    
    # Obtém um laptop pelo ID (busca linear)
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    # Obtém um laptop pelo ID (busca rápida com mapeamento)
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    # Verifica se um preço de promoção é válido (busca linear)
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
            for rowi in self.rows:
                for rowj in self.rows:
                    if rowi[-1] + rowj[-1] == dollars:
                        return True
            return False
    
    # Verifica se um preço de promoção é válido (busca rápida com conjunto)
    def check_promotion_dollars_fast(self, dollars):
        if dollars in self.prices:
            return True
        for price in self.prices:
            if dollars - price in self.prices:
                return True
        return False
    
    # Encontra o índice do primeiro laptop com um preço dado (pesquisa binária)
    def find_laptop_with_price(self, target_price):
        range_start = 0                                   
        range_end = len(self.rows_by_price) - 1                       
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2  
            price = self.rows_by_price[range_middle][-1]
            if price == target_price:                            
                return range_middle                        
            elif price < target_price:                           
                range_start = range_middle + 1             
            else:                                          
                range_end = range_middle - 1 
        price = self.rows_by_price[range_start][-1]
        if price != target_price:                  
            return -1                                      
        return range_start
    
    # Encontra o índice do primeiro laptop mais caro que um preço dado (pesquisa binária)
    def find_first_laptop_more_expensive(self, target_price):
        range_start = 0                                   
        range_end = len(self.rows_by_price) - 1                       
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2  
            price = self.rows_by_price[range_middle][-1]
            if price > target_price:                            
                range_end = range_middle
            else:                           
                range_start = range_middle + 1              
        if self.rows_by_price[range_start][-1] <= target_price:                  
            return -1                                     
        return range_start
    
    # Realiza uma pesquisa por intervalo de preços
    def range_search(self, target_min_price, target_max_price):
        laptops_in_range = []
        start_index = self.find_laptop_with_price(target_min_price)
        
        if start_index == -1:
            return laptops_in_range  # Nenhum laptop encontrado no intervalo
        
        end_index = self.find_first_laptop_more_expensive(target_max_price)
        
        if end_index == -1:
            end_index = len(self.rows_by_price) - 1  # Defina o final como o último laptop disponível
        
        for index in range(start_index, end_index + 1):
            laptops_in_range.append(self.rows_by_price[index])
        
        return laptops_in_range
    
    # Filtra o laptop mais barato com uma determinada RAM e capacidade de HD
    def cheapest_filter(self, size_ram, size_hd):
        for laptop in self.rows_by_price:
            ram_str = laptop[7]  # O índice 7 representa a coluna 'Ram' no CSV
            hd_str = laptop[8]  # O índice 8 representa a coluna 'Memory' no CSV
            price = laptop[-1]  # O último índice representa a coluna 'Price' no CSV

            # Função auxiliar para extrair a quantidade de RAM da string.
            def parse_ram(ram_string):
                try:
                    return int(ram_string.split('GB')[0])
                except ValueError:
                    return 0

            # Função auxiliar para extrair a quantidade de HD da string.
            def parse_hd(hd_string):
                try:
                    if 'GB' in hd_string:
                        return int(hd_string.split('GB')[0])
                    elif 'TB' in hd_string:
                        return int(hd_string.split('TB')[0])*1024
                    else:
                        return 0
                except ValueError:
                    return 0

            ram = parse_ram(ram_str)
            hd = parse_hd(hd_str)
            
            if ram == size_ram and hd == size_hd:
                return laptop
        
# Exemplo de uso:
inventory = Inventory('./docs/laptops.csv')
print(inventory.cheapest_filter(8, 256))
min_price = 400  # Defina o preço mínimo desejado
max_price = 600  # Defina o preço máximo desejado
laptops_in_range = inventory.range_search(min_price, max_price)

if laptops_in_range:
    for laptop in laptops_in_range:
        print(f"ID: {laptop[0]}, Name: {laptop[1]}, RAM: {laptop[7]}, HD: {laptop[8]}, Price: {laptop[-1]}")
else:
    print("Nenhum laptop encontrado dentro do intervalo de preços especificado.")
# Out:
# ['2618101', 'Acer', 'ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)', 'Notebook', '15.6', 'Full HD 1920x1080', 'AMD A8-Series 7410 2.2GHz', '8GB', '256GB SSD', 'AMD Radeon R5', 'Windows 10', '2.23kg', 469]
# ID: 8529462, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 400
# ID: 5322040, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 403
# ID: 4998732, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 403
# ID: 3768307, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 409
# ID: 4185986, Name: Acer, RAM: 6GB, HD: 1TB HDD, Price: 409
# ID: 1463306, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 410
# ID: 5489717, Name: Acer, RAM: 4GB, HD: 128GB SSD, Price: 412
# ID: 7707473, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 414
# ID: 8965582, Name: Asus, RAM: 4GB, HD: 256GB SSD, Price: 415
# ID: 4034740, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 418
# ID: 4934848, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 419
# ID: 7768655, Name: Asus, RAM: 4GB, HD: 128GB SSD, Price: 419
# ID: 4231453, Name: Acer, RAM: 4GB, HD: 128GB SSD, Price: 426
# ID: 3825104, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 428
# ID: 3266159, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 429
# ID: 8927910, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 429
# ID: 2149621, Name: Acer, RAM: 4GB, HD: 128GB SSD, Price: 435
# ID: 3349654, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 435
# ID: 6835419, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 438
# ID: 2501152, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 439
# ID: 9767942, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 439
# ID: 6635237, Name: Dell, RAM: 6GB, HD: 1TB HDD, Price: 439
# ID: 1028124, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 439
# ID: 6175820, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 441
# ID: 6959506, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 443
# ID: 8475301, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 443
# ID: 3779788, Name: Lenovo, RAM: 4GB, HD: 256GB SSD, Price: 444
# ID: 5009762, Name: HP, RAM: 8GB, HD: 128GB SSD, Price: 445
# ID: 6870488, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 447
# ID: 9699902, Name: Toshiba, RAM: 4GB, HD: 500GB HDD, Price: 447
# ID: 7746281, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 449
# ID: 5099862, Name: Acer, RAM: 4GB, HD: 128GB SSD, Price: 449
# ID: 4292336, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 449
# ID: 5439001, Name: Chuwi, RAM: 6GB, HD: 64GB Flash Storage, Price: 449
# ID: 8952373, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 449
# ID: 3734296, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 449
# ID: 4056108, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 450
# ID: 8443579, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 450
# ID: 9117569, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 451
# ID: 2651255, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 455
# ID: 6612197, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 459
# ID: 9605347, Name: Lenovo, RAM: 4GB, HD: 16GB Flash Storage, Price: 459
# ID: 3310709, Name: Lenovo, RAM: 8GB, HD: 2TB HDD, Price: 459
# ID: 4766598, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 459
# ID: 6594248, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 459
# ID: 3530730, Name: Dell, RAM: 6GB, HD: 1TB HDD, Price: 459
# ID: 2398187, Name: Dell, RAM: 6GB, HD: 1TB HDD, Price: 459
# ID: 3017357, Name: Dell, RAM: 6GB, HD: 1TB HDD, Price: 459
# ID: 3092975, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 462
# ID: 9304580, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 465
# ID: 5289853, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 465
# ID: 8118344, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 466
# ID: 5128076, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 467
# ID: 1923343, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 468
# ID: 2091558, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 468
# ID: 8953828, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 469
# ID: 1792978, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 469
# ID: 2618101, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 469
# ID: 7840851, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 469
# ID: 8705589, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 469
# ID: 9038320, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 469
# ID: 5871253, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 469
# ID: 5968254, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 470
# ID: 3283445, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 475
# ID: 9988916, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 476
# ID: 9711541, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 478
# ID: 3805387, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 478
# ID: 8657528, Name: Acer, RAM: 6GB, HD: 1TB HDD, Price: 479
# ID: 3465662, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 479
# ID: 6045964, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 479
# ID: 5822284, Name: Lenovo, RAM: 4GB, HD: 64GB Flash Storage, Price: 479
# ID: 7019058, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 481
# ID: 7882140, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 485
# ID: 2170802, Name: Acer, RAM: 4GB, HD: 128GB Flash Storage, Price: 485
# ID: 1829158, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 485
# ID: 2477848, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 488
# ID: 5910857, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 488
# ID: 3178781, Name: Toshiba, RAM: 4GB, HD: 500GB HDD, Price: 489
# ID: 9411062, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 489
# ID: 5874067, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 489
# ID: 3310330, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 489
# ID: 1464213, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 489
# ID: 6906242, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 489
# ID: 1227101, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 489
# ID: 4080579, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 490
# ID: 8648363, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 493
# ID: 3354615, Name: HP, RAM: 8GB, HD: 64GB Flash Storage, Price: 495
# ID: 5285373, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 498
# ID: 9315979, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 498
# ID: 3252512, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 498
# ID: 2456497, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 499
# ID: 3138857, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 499
# ID: 4882995, Name: Lenovo, RAM: 6GB, HD: 1TB HDD, Price: 499
# ID: 5126178, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 499
# ID: 2428949, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 499
# ID: 9147252, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 499
# ID: 2542810, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 499
# ID: 9900174, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 499
# ID: 5778019, Name: HP, RAM: 4GB, HD: 128GB SSD +  1TB HDD, Price: 499
# ID: 2003310, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 499
# ID: 3465612, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 499
# ID: 3159162, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 500
# ID: 6382974, Name: Asus, RAM: 4GB, HD: 128GB SSD, Price: 509
# ID: 2878339, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 509
# ID: 2751361, Name: Lenovo, RAM: 8GB, HD: 2TB HDD, Price: 519
# ID: 1998281, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 519
# ID: 8866576, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 519
# ID: 7120412, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 520
# ID: 5468624, Name: HP, RAM: 4GB, HD: 1TB HDD, Price: 521
# ID: 4636240, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 521
# ID: 8646050, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 522
# ID: 3619773, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 523
# ID: 6256458, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 529
# ID: 3547352, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 529
# ID: 4662064, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 530
# ID: 7704409, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 530
# ID: 2418086, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 535
# ID: 8100250, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 539
# ID: 5780284, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 539
# ID: 5601221, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 539
# ID: 1897616, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 539
# ID: 9854841, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 540
# ID: 7895184, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 544
# ID: 2260492, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 544
# ID: 2633512, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 545
# ID: 9293777, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 547
# ID: 9592111, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 549
# ID: 3205502, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 549
# ID: 2187552, Name: Lenovo, RAM: 8GB, HD: 2TB HDD, Price: 549
# ID: 8949300, Name: Acer, RAM: 6GB, HD: 1TB HDD, Price: 549
# ID: 2710556, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 549
# ID: 4583354, Name: Lenovo, RAM: 6GB, HD: 256GB SSD, Price: 549
# ID: 1473102, Name: Lenovo, RAM: 4GB, HD: 64GB Flash Storage, Price: 549
# ID: 9781675, Name: HP, RAM: 6GB, HD: 1.0TB Hybrid, Price: 549
# ID: 6608535, Name: HP, RAM: 6GB, HD: 1.0TB Hybrid, Price: 549
# ID: 9252539, Name: HP, RAM: 6GB, HD: 1.0TB Hybrid, Price: 549
# ID: 4508969, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 553
# ID: 6050061, Name: Dell, RAM: 8GB, HD: 2TB HDD, Price: 557
# ID: 9506451, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 558
# ID: 5458109, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 559
# ID: 8970088, Name: Asus, RAM: 4GB, HD: 256GB SSD, Price: 559
# ID: 7822218, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 559
# ID: 7235583, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 559
# ID: 2331050, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 564
# ID: 9165471, Name: Lenovo, RAM: 6GB, HD: 1TB HDD, Price: 564
# ID: 9592036, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 565
# ID: 1408165, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 565
# ID: 3858788, Name: HP, RAM: 6GB, HD: 128GB SSD, Price: 568
# ID: 7363621, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 569
# ID: 4741948, Name: HP, RAM: 6GB, HD: 2TB HDD, Price: 569
# ID: 6862412, Name: Lenovo, RAM: 6GB, HD: 128GB SSD, Price: 569
# ID: 4462539, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 572
# ID: 3910184, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 573
# ID: 3362737, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 575
# ID: 3275171, Name: Asus, RAM: 4GB, HD: 128GB SSD +  1TB HDD, Price: 575
# ID: 8013260, Name: Asus, RAM: 6GB, HD: 256GB SSD, Price: 577
# ID: 7851464, Name: Lenovo, RAM: 6GB, HD: 256GB SSD, Price: 579
# ID: 5618176, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 579
# ID: 8812033, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 579
# ID: 6506609, Name: Asus, RAM: 4GB, HD: 1TB HDD, Price: 579
# ID: 8370494, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 579
# ID: 9932887, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 579
# ID: 5819389, Name: Asus, RAM: 8GB, HD: 128GB SSD, Price: 581
# ID: 6594000, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 585
# ID: 1268022, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 585
# ID: 2776651, Name: Asus, RAM: 4GB, HD: 256GB SSD, Price: 586
# ID: 1273121, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 586
# ID: 1711480, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 589
# ID: 6934548, Name: Lenovo, RAM: 8GB, HD: 128GB SSD, Price: 589
# ID: 1785326, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 589
# ID: 4741706, Name: HP, RAM: 8GB, HD: 128GB SSD, Price: 589
# ID: 7770328, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 589
# ID: 2125555, Name: Asus, RAM: 8GB, HD: 128GB HDD, Price: 590
# ID: 5028014, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 597
# ID: 3016600, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 597
# ID: 7092736, Name: Lenovo, RAM: 6GB, HD: 256GB SSD, Price: 597
# ID: 6806574, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 598
# ID: 8806430, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 598
# ID: 3277178, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 598
# ID: 8903727, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 598
# ID: 1406454, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 599
# ID: 4570427, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 599
# ID: 6712628, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 599
# ID: 4054079, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 599
# ID: 1633452, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 599
# ID: 7262162, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 599
# ID: 8074324, Name: Toshiba, RAM: 4GB, HD: 500GB HDD, Price: 602
# ID: 2220999, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 603
# ID: 5329753, Name: Lenovo, RAM: 12GB, HD: 1TB HDD, Price: 609
# ID: 5024394, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 609
# ID: 4678754, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 612
# ID: 6754452, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 613
# ID: 5060583, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 614
# ID: 8407208, Name: HP, RAM: 4GB, HD: 32GB Flash Storage, Price: 615
# ID: 8321675, Name: HP, RAM: 4GB, HD: 32GB Flash Storage, Price: 615
# ID: 3613743, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 616
# ID: 8005269, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 617
# ID: 3447895, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 618
# ID: 7992512, Name: HP, RAM: 6GB, HD: 256GB SSD, Price: 619
# ID: 2379645, Name: Acer, RAM: 8GB, HD: 128GB SSD, Price: 619
# ID: 9828851, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 619
# ID: 8084150, Name: Lenovo, RAM: 4GB, HD: 1TB HDD +  1TB HDD, Price: 621
# ID: 2078302, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 629
# ID: 5881306, Name: Lenovo, RAM: 4GB, HD: 256GB SSD, Price: 629
# ID: 9559405, Name: HP, RAM: 8GB, HD: 2TB HDD, Price: 629
# ID: 2579214, Name: HP, RAM: 8GB, HD: 2TB HDD, Price: 629
# ID: 7555958, Name: Lenovo, RAM: 8GB, HD: 500GB HDD, Price: 629
# ID: 5860283, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 629
# ID: 2317731, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 630
# ID: 2488065, Name: Acer, RAM: 4GB, HD: 128GB SSD, Price: 636
# ID: 5135236, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 638
# ID: 7050429, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 638
# ID: 1513407, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 638
# ID: 8610376, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 638
# ID: 5294744, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 638
# ID: 3048980, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 639
# ID: 5895007, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 639
# ID: 4291947, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 639
# ID: 4717816, Name: Acer, RAM: 4GB, HD: 500GB HDD, Price: 639
# ID: 7692042, Name: Asus, RAM: 6GB, HD: 1TB HDD, Price: 639
# ID: 3762176, Name: Lenovo, RAM: 4GB, HD: 64GB Flash Storage, Price: 646
# ID: 5052792, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 647
# ID: 9102590, Name: Lenovo, RAM: 6GB, HD: 1TB HDD, Price: 649
# ID: 1719039, Name: HP, RAM: 6GB, HD: 256GB SSD, Price: 649
# ID: 6862043, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 649
# ID: 8238980, Name: Dell, RAM: 12GB, HD: 1TB HDD, Price: 649
# ID: 6199330, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 649
# ID: 4474453, Name: Fujitsu, RAM: 4GB, HD: 256GB SSD, Price: 649
# ID: 5987877, Name: HP, RAM: 6GB, HD: 128GB SSD +  1TB HDD, Price: 650
# ID: 3957732, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 650
# ID: 9114722, Name: Acer, RAM: 4GB, HD: 1TB HDD, Price: 655
# ID: 7075274, Name: HP, RAM: 6GB, HD: 2TB HDD, Price: 655
# ID: 5293870, Name: Acer, RAM: 4GB, HD: 128GB SSD, Price: 655
# ID: 6805422, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 657
# ID: 1135884, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 659
# ID: 6144839, Name: HP, RAM: 6GB, HD: 256GB SSD, Price: 659
# ID: 4493683, Name: Acer, RAM: 12GB, HD: 1TB HDD, Price: 659
# ID: 5597869, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 659
# ID: 2293266, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 659
# ID: 6960192, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 659
# ID: 5769206, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 659
# ID: 8111334, Name: Lenovo, RAM: 8GB, HD: 1.0TB HDD, Price: 659
# ID: 2823902, Name: Samsung, RAM: 4GB, HD: 32GB Flash Storage, Price: 659
# ID: 3977698, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 663
# ID: 2949057, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 665
# ID: 7322853, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 668
# ID: 9138937, Name: Asus, RAM: 4GB, HD: 64GB Flash Storage, Price: 669
# ID: 6923677, Name: Toshiba, RAM: 4GB, HD: 500GB HDD, Price: 669
# ID: 8117261, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 669
# ID: 3055367, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 675
# ID: 6223157, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 675
# ID: 9005892, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 677
# ID: 2921108, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 679
# ID: 8782884, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 682
# ID: 5220145, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 684
# ID: 7601699, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 684
# ID: 4858128, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 684
# ID: 8622300, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 685
# ID: 3990734, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 685
# ID: 8940863, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 685
# ID: 4592224, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 689
# ID: 7512130, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 689
# ID: 5889537, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 689
# ID: 4568693, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 689
# ID: 1684094, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 689
# ID: 8671263, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 690
# ID: 9445233, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 691
# ID: 7342677, Name: Acer, RAM: 12GB, HD: 1TB HDD, Price: 693
# ID: 9119246, Name: Lenovo, RAM: 6GB, HD: 256GB SSD, Price: 695
# ID: 7621404, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 698
# ID: 3860695, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 699
# ID: 1945846, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 699
# ID: 1460190, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 699
# ID: 3560567, Name: HP, RAM: 6GB, HD: 2TB HDD, Price: 699
# ID: 8221945, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 699
# ID: 4910469, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 699
# ID: 9913428, Name: Lenovo, RAM: 4GB, HD: 256GB SSD, Price: 699
# ID: 5455416, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 702
# ID: 5252103, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 705
# ID: 2286683, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 705
# ID: 4765534, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 708
# ID: 8416477, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 709
# ID: 6819784, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 709
# ID: 9100292, Name: Dell, RAM: 12GB, HD: 1TB HDD, Price: 713
# ID: 5697288, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 713
# ID: 8837038, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 716
# ID: 7283234, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 719
# ID: 9606174, Name: Lenovo, RAM: 6GB, HD: 128GB SSD +  1TB HDD, Price: 719
# ID: 4558723, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 719
# ID: 7510869, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 719
# ID: 2988937, Name: Asus, RAM: 4GB, HD: 500GB HDD, Price: 720
# ID: 9642273, Name: Asus, RAM: 4GB, HD: 500GB HDD, Price: 720
# ID: 6931731, Name: Asus, RAM: 4GB, HD: 500GB HDD, Price: 720
# ID: 7497980, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 722
# ID: 5346081, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 722
# ID: 3423499, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 726
# ID: 7032044, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 726
# ID: 7196316, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 728
# ID: 1999945, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 729
# ID: 9134926, Name: Asus, RAM: 8GB, HD: 512GB SSD, Price: 729
# ID: 1490009, Name: Asus, RAM: 8GB, HD: 512GB SSD, Price: 729
# ID: 5358634, Name: Asus, RAM: 8GB, HD: 512GB SSD, Price: 729
# ID: 7371561, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 735
# ID: 1286032, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 735
# ID: 6599316, Name: Lenovo, RAM: 4GB, HD: 180GB SSD, Price: 735
# ID: 9969570, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 737
# ID: 6828442, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 739
# ID: 9248871, Name: Fujitsu, RAM: 8GB, HD: 1TB HDD, Price: 739
# ID: 9507949, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 739
# ID: 1694389, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 739
# ID: 2347020, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 739
# ID: 2363883, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 740
# ID: 5060088, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 742
# ID: 6827877, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 742
# ID: 9299321, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 744
# ID: 8371792, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 745
# ID: 5752499, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 745
# ID: 7516903, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 745
# ID: 8537981, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 749
# ID: 3602417, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 749
# ID: 5322452, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 749
# ID: 6762391, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 749
# ID: 5309221, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 750
# ID: 3371187, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 752
# ID: 3105555, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 754
# ID: 7861256, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 755
# ID: 8440789, Name: Dell, RAM: 8GB, HD: 2TB HDD, Price: 759
# ID: 1665350, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 764
# ID: 8977838, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 764
# ID: 2490800, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 764
# ID: 3201203, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 767
# ID: 2579949, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 769
# ID: 5017836, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 769
# ID: 3997689, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 769
# ID: 2618217, Name: Asus, RAM: 4GB, HD: 256GB SSD, Price: 769
# ID: 9202701, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 770
# ID: 3312709, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 775
# ID: 8489997, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 776
# ID: 7244694, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 778
# ID: 6280119, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 779
# ID: 1922158, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 779
# ID: 3917027, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 779
# ID: 6538891, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 779
# ID: 7913362, Name: Toshiba, RAM: 4GB, HD: 500GB HDD, Price: 780
# ID: 5563916, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 784
# ID: 6187500, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 785
# ID: 3484842, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 787
# ID: 1056057, Name: Lenovo, RAM: 8GB, HD: 1.0TB Hybrid, Price: 788
# ID: 5336732, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 789
# ID: 4333300, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 789
# ID: 1190809, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 789
# ID: 9482233, Name: Lenovo, RAM: 6GB, HD: 256GB SSD, Price: 789
# ID: 5895262, Name: Toshiba, RAM: 8GB, HD: 128GB SSD, Price: 793
# ID: 3284519, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 794
# ID: 5447560, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 795
# ID: 7837521, Name: Dell, RAM: 4GB, HD: 1TB HDD, Price: 795
# ID: 6801203, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 797
# ID: 5988701, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 798
# ID: 1754994, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 798
# ID: 3714210, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 799
# ID: 9715794, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 799
# ID: 6456744, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 799
# ID: 7252026, Name: Fujitsu, RAM: 8GB, HD: 256GB SSD, Price: 799
# ID: 5567668, Name: Acer, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 799
# ID: 3849318, Name: HP, RAM: 6GB, HD: 1TB HDD, Price: 799
# ID: 5634391, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 800
# ID: 6886099, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 800
# ID: 5195468, Name: Acer, RAM: 4GB, HD: 256GB SSD, Price: 805
# ID: 1012887, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 805
# ID: 2955598, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 805
# ID: 2845549, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 805
# ID: 1595010, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 806
# ID: 1268870, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 809
# ID: 5069567, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 810
# ID: 5630248, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 812
# ID: 9952171, Name: Toshiba, RAM: 8GB, HD: 500GB HDD, Price: 812
# ID: 3093053, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 813
# ID: 6348436, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 817
# ID: 4594338, Name: Dell, RAM: 4GB, HD: 256GB SSD, Price: 818
# ID: 1940272, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 819
# ID: 8005325, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 819
# ID: 9169853, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 819
# ID: 3615714, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 819
# ID: 9747224, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 819
# ID: 6888074, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 825
# ID: 9858096, Name: Lenovo, RAM: 4GB, HD: 1.0TB Hybrid, Price: 825
# ID: 7040804, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 829
# ID: 8976452, Name: Lenovo, RAM: 4GB, HD: 256GB SSD, Price: 829
# ID: 5472768, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 830
# ID: 7476438, Name: Lenovo, RAM: 6GB, HD: 256GB SSD, Price: 831
# ID: 5075075, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 832
# ID: 2434088, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 833
# ID: 6924027, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 836
# ID: 4726891, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 836
# ID: 5453672, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 839
# ID: 6180401, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 839
# ID: 3213976, Name: Asus, RAM: 12GB, HD: 2TB HDD, Price: 839
# ID: 9302837, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 839
# ID: 9101928, Name: MSI, RAM: 8GB, HD: 1TB HDD, Price: 839
# ID: 1786745, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 841
# ID: 9064647, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 844
# ID: 6676364, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 846
# ID: 1689001, Name: Acer, RAM: 8GB, HD: 1TB HDD, Price: 846
# ID: 7355294, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 846
# ID: 8421453, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 847
# ID: 7248846, Name: Lenovo, RAM: 4GB, HD: 256GB SSD, Price: 847
# ID: 2811904, Name: Lenovo, RAM: 8GB, HD: 2TB HDD, Price: 849
# ID: 7000811, Name: Asus, RAM: 4GB, HD: 256GB SSD, Price: 849
# ID: 7045578, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 849
# ID: 9849850, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 850
# ID: 9494115, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 854
# ID: 6107447, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 855
# ID: 7959358, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 857
# ID: 7436397, Name: Dell, RAM: 16GB, HD: 1TB HDD, Price: 859
# ID: 8259646, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 859
# ID: 1667803, Name: Lenovo, RAM: 6GB, HD: 128GB SSD +  1TB HDD, Price: 859
# ID: 5397402, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 859
# ID: 8225398, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 860
# ID: 5376127, Name: Toshiba, RAM: 8GB, HD: 500GB HDD, Price: 860
# ID: 1529860, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 865
# ID: 7353700, Name: Lenovo, RAM: 4GB, HD: 256GB SSD, Price: 867
# ID: 6085824, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 869
# ID: 8312235, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 869
# ID: 9172061, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 869
# ID: 6152791, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 870
# ID: 6729956, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 875
# ID: 8367566, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 879
# ID: 8845657, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 879
# ID: 4688003, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 879
# ID: 8681714, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 879
# ID: 6735575, Name: Dell, RAM: 16GB, HD: 1TB HDD, Price: 879
# ID: 5587263, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 880
# ID: 5980403, Name: Lenovo, RAM: 4GB, HD: 128GB SSD, Price: 881
# ID: 2618138, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 884
# ID: 1374202, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 889
# ID: 3664034, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 889
# ID: 9317246, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 889
# ID: 3890464, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 889
# ID: 4600839, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 889
# ID: 3301667, Name: Asus, RAM: 8GB, HD: 256GB SSD +  500GB HDD, Price: 891
# ID: 8716939, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 895
# ID: 3507379, Name: Lenovo, RAM: 8GB, HD: 1.0TB Hybrid, Price: 895
# ID: 9600663, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 896
# ID: 7287764, Name: Apple, RAM: 8GB, HD: 128GB Flash Storage, Price: 898
# ID: 9636255, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 898
# ID: 8959799, Name: Dell, RAM: 8GB, HD: 1.0TB Hybrid, Price: 899
# ID: 9390454, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 899
# ID: 7106466, Name: Dell, RAM: 16GB, HD: 256GB SSD, Price: 899
# ID: 7523657, Name: Lenovo, RAM: 12GB, HD: 2TB HDD, Price: 899
# ID: 7130324, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 899
# ID: 7384405, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 899
# ID: 6218853, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 899
# ID: 4358763, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 899
# ID: 9166425, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 899
# ID: 3377565, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 899
# ID: 1860651, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 899
# ID: 9020399, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 900
# ID: 3218997, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 902
# ID: 5391856, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 902
# ID: 4231761, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 906
# ID: 6865594, Name: Asus, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 909
# ID: 6659823, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 910
# ID: 9646524, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 910
# ID: 9163575, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 911
# ID: 6295156, Name: Dell, RAM: 4GB, HD: 128GB SSD +  1TB HDD, Price: 912
# ID: 3606207, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 914
# ID: 6092016, Name: Toshiba, RAM: 4GB, HD: 500GB HDD, Price: 915
# ID: 1701173, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 919
# ID: 7264795, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 919
# ID: 1525448, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 923
# ID: 2355172, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 928
# ID: 6047308, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 928
# ID: 7386757, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 929
# ID: 9354140, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 931
# ID: 1178786, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 932
# ID: 2439403, Name: Xiaomi, RAM: 8GB, HD: 256GB SSD, Price: 935
# ID: 2668103, Name: Dell, RAM: 8GB, HD: 500GB HDD, Price: 935
# ID: 2724402, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 938
# ID: 1538812, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 938
# ID: 4600984, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 940
# ID: 6337731, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 941
# ID: 8947698, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 943
# ID: 7837602, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 945
# ID: 3372480, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 945
# ID: 8544205, Name: Asus, RAM: 12GB, HD: 1TB HDD, Price: 949
# ID: 5741011, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 949
# ID: 5635613, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 949
# ID: 9131644, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 949
# ID: 9741930, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 949
# ID: 5229469, Name: Lenovo, RAM: 6GB, HD: 128GB SSD +  1TB HDD, Price: 949
# ID: 3067292, Name: Lenovo, RAM: 12GB, HD: 512GB SSD, Price: 949
# ID: 7729599, Name: Dell, RAM: 8GB, HD: 1.0TB Hybrid, Price: 949
# ID: 8664016, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 951
# ID: 4682835, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 955
# ID: 3295843, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 955
# ID: 6592668, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 959
# ID: 8329450, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 959
# ID: 6145520, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 959
# ID: 7546603, Name: Apple, RAM: 4GB, HD: 256GB Flash Storage, Price: 959
# ID: 5062733, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 960
# ID: 1961990, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 960
# ID: 1553787, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 961
# ID: 3444668, Name: Dell, RAM: 8GB, HD: 128GB SSD +  2TB HDD, Price: 970
# ID: 6407922, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 973
# ID: 5666663, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 973
# ID: 5210941, Name: HP, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 977
# ID: 3314732, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 977
# ID: 2965574, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 977
# ID: 4991632, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 979
# ID: 4621708, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 979
# ID: 3836511, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 979
# ID: 6936735, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 979
# ID: 9951552, Name: HP, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 979
# ID: 3736040, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 979
# ID: 2481827, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 979
# ID: 3735815, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 980
# ID: 7504936, Name: Dell, RAM: 8GB, HD: 128GB SSD +  2TB HDD, Price: 985
# ID: 3308866, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 985
# ID: 9750975, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 988
# ID: 5141214, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 989
# ID: 6143026, Name: Microsoft, RAM: 4GB, HD: 128GB SSD, Price: 989
# ID: 6236474, Name: Dell, RAM: 16GB, HD: 2TB HDD, Price: 989
# ID: 4702771, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 989
# ID: 1616058, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 990
# ID: 1980644, Name: MSI, RAM: 8GB, HD: 256GB SSD, Price: 997
# ID: 2877805, Name: Apple, RAM: 8GB, HD: 256GB Flash Storage, Price: 998
# ID: 1375681, Name: Asus, RAM: 16GB, HD: 1TB HDD, Price: 998
# ID: 5650428, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 999
# ID: 2459229, Name: Dell, RAM: 12GB, HD: 1TB HDD, Price: 999
# ID: 1283932, Name: Xiaomi, RAM: 8GB, HD: 256GB SSD, Price: 999
# ID: 9137264, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 999
# ID: 7524229, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 999
# ID: 1315593, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 999
# ID: 9703217, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 999
# ID: 8573508, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 999
# ID: 1159748, Name: Lenovo, RAM: 4GB, HD: 1TB HDD, Price: 999
# ID: 6210340, Name: Lenovo, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 999
# ID: 9505275, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 999
# ID: 6676297, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 1000
# ID: 8747948, Name: Lenovo, RAM: 4GB, HD: 508GB Hybrid, Price: 1002
# ID: 5550925, Name: Dell, RAM: 8GB, HD: 500GB HDD, Price: 1008
# ID: 3667708, Name: Acer, RAM: 12GB, HD: 128GB SSD +  1TB HDD, Price: 1009
# ID: 8017281, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1009
# ID: 6766298, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1010
# ID: 9303831, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1010
# ID: 5590223, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1011
# ID: 7107556, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 1017
# ID: 6632931, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 1018
# ID: 6413052, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1018
# ID: 2753795, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 1020
# ID: 8409336, Name: Asus, RAM: 8GB, HD: 512GB SSD, Price: 1026
# ID: 7697584, Name: MSI, RAM: 8GB, HD: 256GB SSD, Price: 1027
# ID: 4989851, Name: Razer, RAM: 8GB, HD: 256GB SSD, Price: 1029
# ID: 3791046, Name: Lenovo, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 1029
# ID: 7213947, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 1030
# ID: 7998232, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1031
# ID: 6095437, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1034
# ID: 5953806, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 1039
# ID: 4751933, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1043
# ID: 9101682, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1045
# ID: 6491997, Name: Dell, RAM: 8GB, HD: 500GB HDD, Price: 1046
# ID: 1426493, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1048
# ID: 7320484, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1049
# ID: 8819887, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1049
# ID: 9952432, Name: Dell, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 1049
# ID: 4766129, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1049
# ID: 8887221, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1049
# ID: 9248942, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1049
# ID: 2003272, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1049
# ID: 3286359, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1049
# ID: 8327331, Name: Lenovo, RAM: 4GB, HD: 500GB HDD, Price: 1055
# ID: 4767334, Name: HP, RAM: 16GB, HD: 1TB HDD, Price: 1059
# ID: 4184568, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1060
# ID: 9134293, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 1060
# ID: 9539057, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1062
# ID: 6652716, Name: Toshiba, RAM: 8GB, HD: 500GB HDD, Price: 1064
# ID: 3586299, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1070
# ID: 1738460, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1072
# ID: 9732542, Name: Lenovo, RAM: 16GB, HD: 256GB SSD, Price: 1079
# ID: 3304683, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1079
# ID: 9783620, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1080
# ID: 5404773, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1082
# ID: 3490949, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1084
# ID: 3316902, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1085
# ID: 4762286, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1085
# ID: 3775619, Name: Microsoft, RAM: 4GB, HD: 128GB SSD, Price: 1089
# ID: 7575614, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1089
# ID: 5464198, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1089
# ID: 1681112, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 1090
# ID: 7910067, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1090
# ID: 4910981, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1094
# ID: 2056366, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1094
# ID: 9554426, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1095
# ID: 3503096, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1095
# ID: 1588927, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1096
# ID: 9793241, Name: Lenovo, RAM: 4GB, HD: 180GB SSD, Price: 1096
# ID: 6178022, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1097
# ID: 8264992, Name: Apple, RAM: 8GB, HD: 128GB Flash Storage, Price: 1099
# ID: 3945452, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1099
# ID: 9000126, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1099
# ID: 8607450, Name: Asus, RAM: 12GB, HD: 512GB SSD +  2TB HDD, Price: 1099
# ID: 8204777, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1099
# ID: 8570885, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1099
# ID: 3711170, Name: HP, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1099
# ID: 4676586, Name: Lenovo, RAM: 8GB, HD: 180GB SSD, Price: 1099
# ID: 1856015, Name: HP, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1099
# ID: 9522790, Name: Dell, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 1099
# ID: 1853360, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 1099
# ID: 4568930, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1099
# ID: 4324417, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1099
# ID: 9251441, Name: Lenovo, RAM: 16GB, HD: 1.0TB Hybrid, Price: 1099
# ID: 5977892, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1099
# ID: 3310447, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1099
# ID: 8036099, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1103
# ID: 5342965, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 1105
# ID: 7157825, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1109
# ID: 7290561, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1116
# ID: 1520270, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1116
# ID: 8380492, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1118
# ID: 8728122, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1119
# ID: 4722392, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1119
# ID: 1460647, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1119
# ID: 8152546, Name: Dell, RAM: 8GB, HD: 128GB SSD, Price: 1119
# ID: 8314710, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1124
# ID: 3604207, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1126
# ID: 7205424, Name: Lenovo, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 1129
# ID: 6253635, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1129
# ID: 1724555, Name: HP, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1129
# ID: 4044754, Name: Dell, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1130
# ID: 5332509, Name: Dell, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 1135
# ID: 2964317, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1135
# ID: 1671943, Name: Dell, RAM: 4GB, HD: 500GB HDD, Price: 1135
# ID: 9869141, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1142
# ID: 5561715, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1142
# ID: 1849371, Name: Dell, RAM: 8GB, HD: 256GB SSD +  2TB HDD, Price: 1142
# ID: 3025664, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1142
# ID: 9887950, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1144
# ID: 2792537, Name: Lenovo, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1144
# ID: 3011384, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1145
# ID: 3007298, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1145
# ID: 3051038, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1149
# ID: 1595818, Name: Lenovo, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1149
# ID: 6585088, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1149
# ID: 3263711, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 1149
# ID: 9116083, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1149
# ID: 3315262, Name: Acer, RAM: 8GB, HD: 256GB SSD, Price: 1149
# ID: 5767190, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1149
# ID: 6407618, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1150
# ID: 2047297, Name: HP, RAM: 8GB, HD: 500GB HDD, Price: 1154
# ID: 3824690, Name: Apple, RAM: 8GB, HD: 256GB Flash Storage, Price: 1158
# ID: 5155985, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1159
# ID: 2012321, Name: Asus, RAM: 8GB, HD: 64GB Flash Storage, Price: 1159
# ID: 4353149, Name: HP, RAM: 16GB, HD: 512GB SSD, Price: 1159
# ID: 3627718, Name: Apple, RAM: 8GB, HD: 256GB Flash Storage, Price: 1163
# ID: 1913954, Name: Apple, RAM: 8GB, HD: 512GB Flash Storage, Price: 1165
# ID: 5988429, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1165
# ID: 9385935, Name: Dell, RAM: 4GB, HD: 128GB SSD, Price: 1166
# ID: 8736671, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1168
# ID: 5187293, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 1169
# ID: 3822728, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 1169
# ID: 9122597, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1169
# ID: 9254579, Name: Lenovo, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1179
# ID: 6568761, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1179
# ID: 4922502, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1179
# ID: 7937210, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1179
# ID: 2552355, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1180
# ID: 2349429, Name: Dell, RAM: 16GB, HD: 256GB SSD, Price: 1181
# ID: 4856792, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1185
# ID: 7442374, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1186
# ID: 4356626, Name: Asus, RAM: 8GB, HD: 1TB HDD, Price: 1187
# ID: 4096833, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1189
# ID: 5352719, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1189
# ID: 1948508, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 1189
# ID: 3394169, Name: HP, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1191
# ID: 8903657, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1191
# ID: 4646237, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1191
# ID: 9081492, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1191
# ID: 7343930, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1193
# ID: 1532735, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1195
# ID: 4112749, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 1195
# ID: 6167927, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 1195
# ID: 6993352, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1195
# ID: 1035430, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1196
# ID: 8332567, Name: HP, RAM: 16GB, HD: 512GB SSD, Price: 1197
# ID: 2891079, Name: Xiaomi, RAM: 8GB, HD: 256GB SSD, Price: 1199
# ID: 9025650, Name: MSI, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1199
# ID: 9819756, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1199
# ID: 3944223, Name: MSI, RAM: 8GB, HD: 256GB SSD, Price: 1199
# ID: 6891932, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1199
# ID: 9043491, Name: HP, RAM: 4GB, HD: 500GB HDD, Price: 1199
# ID: 6585456, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1199
# ID: 3852781, Name: Lenovo, RAM: 8GB, HD: 180GB SSD, Price: 1199
# ID: 2091722, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1199
# ID: 5926363, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 1199
# ID: 9028862, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1199
# ID: 6238133, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1200
# ID: 8932762, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1205
# ID: 3715314, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1205
# ID: 3792326, Name: Dell, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1207
# ID: 6007157, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1210
# ID: 7967441, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1213
# ID: 5247058, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1215
# ID: 9898762, Name: Dell, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 1219
# ID: 3700984, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1219
# ID: 7078924, Name: Asus, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1224
# ID: 4225514, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1228
# ID: 9111452, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1229
# ID: 1445640, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1229
# ID: 6585910, Name: MSI, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1229
# ID: 7700245, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1244
# ID: 7076485, Name: HP, RAM: 12GB, HD: 128GB SSD +  1TB HDD, Price: 1249
# ID: 1771635, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1249
# ID: 7875051, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1249
# ID: 2042182, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1258
# ID: 6496389, Name: Acer, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1260
# ID: 5474670, Name: Apple, RAM: 8GB, HD: 256GB SSD, Price: 1262
# ID: 8722877, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1262
# ID: 5305628, Name: Dell, RAM: 8GB, HD: 512GB SSD, Price: 1262
# ID: 6318733, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1265
# ID: 3083548, Name: HP, RAM: 4GB, HD: 128GB SSD, Price: 1265
# ID: 2622610, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1268
# ID: 2463861, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1268
# ID: 4958992, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 1269
# ID: 8100929, Name: Asus, RAM: 24GB, HD: 256GB SSD +  1TB HDD, Price: 1269
# ID: 1536513, Name: HP, RAM: 16GB, HD: 512GB SSD, Price: 1271
# ID: 1615409, Name: Lenovo, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1272
# ID: 3441250, Name: Google, RAM: 8GB, HD: 128GB SSD, Price: 1275
# ID: 7412947, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1279
# ID: 7003168, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1279
# ID: 5830728, Name: Asus, RAM: 32GB, HD: 256GB SSD +  256GB SSD, Price: 1279
# ID: 7888432, Name: Apple, RAM: 8GB, HD: 512GB Flash Storage, Price: 1279
# ID: 1185406, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 1280
# ID: 8618610, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1280
# ID: 1353171, Name: Toshiba, RAM: 4GB, HD: 128GB SSD, Price: 1285
# ID: 7293900, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1285
# ID: 9851339, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1292
# ID: 7201308, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1294
# ID: 8234038, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1296
# ID: 7406268, Name: Dell, RAM: 8GB, HD: 256GB SSD +  256GB SSD, Price: 1298
# ID: 7965266, Name: Asus, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1299
# ID: 4959661, Name: Dell, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 1299
# ID: 1656518, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1299
# ID: 6828416, Name: Lenovo, RAM: 8GB, HD: 1TB HDD, Price: 1299
# ID: 9414579, Name: Asus, RAM: 12GB, HD: 128GB SSD +  1TB HDD, Price: 1299
# ID: 1084004, Name: Asus, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1299
# ID: 1939641, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1299
# ID: 7206465, Name: Acer, RAM: 16GB, HD: 256GB SSD, Price: 1299
# ID: 8204918, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1299
# ID: 2814983, Name: Dell, RAM: 12GB, HD: 512GB SSD, Price: 1299
# ID: 8826916, Name: Dell, RAM: 12GB, HD: 256GB SSD, Price: 1299
# ID: 9404297, Name: Apple, RAM: 8GB, HD: 256GB Flash Storage, Price: 1300
# ID: 1630305, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1304
# ID: 7550576, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1305
# ID: 6127073, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1312
# ID: 5501601, Name: Asus, RAM: 8GB, HD: 256GB SSD, Price: 1315
# ID: 9598638, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1323
# ID: 4576846, Name: HP, RAM: 12GB, HD: 128GB SSD +  1TB HDD, Price: 1327
# ID: 2967207, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1329
# ID: 5657100, Name: Asus, RAM: 8GB, HD: 256GB SSD +  1TB HDD, Price: 1334
# ID: 9636126, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1335
# ID: 6571244, Name: Apple, RAM: 8GB, HD: 128GB SSD, Price: 1339
# ID: 2104206, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1339
# ...
# ID: 2805625, Name: Samsung, RAM: 8GB, HD: 256GB SSD, Price: 1699
# ID: 1858110, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1699
# ID: 9722469, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1700
# ID: 1059303, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1713
# ID: 1434855, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1713
# ID: 8231788, Name: Toshiba, RAM: 8GB, HD: 256GB SSD, Price: 1725
# ID: 1536532, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1729
# ID: 1657927, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1738
# ID: 7040500, Name: Toshiba, RAM: 16GB, HD: 512GB SSD, Price: 1747
# ID: 5485780, Name: Asus, RAM: 16GB, HD: 512GB SSD, Price: 1748
# ID: 7003481, Name: Lenovo, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 1749
# ID: 4264201, Name: HP, RAM: 8GB, HD: 1TB SSD, Price: 1749
# ID: 3113401, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1749
# ID: 7250657, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1749
# ID: 2317778, Name: HP, RAM: 12GB, HD: 1TB HDD, Price: 1749
# ID: 6460063, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1749
# ID: 8563087, Name: Asus, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 1749
# ID: 6343880, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1750
# ID: 2330390, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1757
# ID: 3878517, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1760
# ID: 1015923, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1763
# ID: 3900703, Name: Toshiba, RAM: 16GB, HD: 512GB SSD, Price: 1764
# ID: 4962242, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1769
# ID: 7882716, Name: Asus, RAM: 8GB, HD: 128GB SSD +  1TB HDD, Price: 1770
# ID: 3422023, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1775
# ID: 7882354, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 1778
# ID: 7498575, Name: Toshiba, RAM: 8GB, HD: 512GB SSD, Price: 1790
# ID: 1733409, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1798
# ID: 1222930, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1799
# ID: 1836483, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1799
# ID: 9094170, Name: Microsoft, RAM: 8GB, HD: 256GB SSD, Price: 1799
# ID: 3373482, Name: HP, RAM: 12GB, HD: 1TB HDD, Price: 1799
# ID: 2489224, Name: Samsung, RAM: 16GB, HD: 256GB SSD, Price: 1799
# ID: 2940612, Name: Razer, RAM: 16GB, HD: 512GB SSD, Price: 1799
# ID: 7458125, Name: Asus, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 1799
# ID: 2295224, Name: HP, RAM: 4GB, HD: 256GB SSD, Price: 1799
# ID: 5005034, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1799
# ID: 2666332, Name: Lenovo, RAM: 16GB, HD: 1TB SSD, Price: 1799
# ID: 2658907, Name: Asus, RAM: 16GB, HD: 512GB SSD +  2TB HDD, Price: 1799
# ID: 5416359, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1799
# ID: 9696048, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1799
# ID: 3138039, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1799
# ID: 8550527, Name: Apple, RAM: 8GB, HD: 256GB SSD, Price: 1803
# ID: 6754784, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1813
# ID: 2428795, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1819
# ID: 9748627, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1820
# ID: 7411814, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1825
# ID: 4658909, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1829
# ID: 4580639, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1841
# ID: 4862478, Name: Dell, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 1845
# ID: 4442628, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1849
# ID: 7703253, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1849
# ID: 4266899, Name: Samsung, RAM: 16GB, HD: 256GB SSD, Price: 1849
# ID: 1627187, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1855
# ID: 3403764, Name: Lenovo, RAM: 12GB, HD: 256GB SSD, Price: 1858
# ID: 9592377, Name: Dell, RAM: 16GB, HD: 256GB SSD, Price: 1859
# ID: 2877453, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1859
# ID: 7766275, Name: HP, RAM: 8GB, HD: 500GB HDD, Price: 1860
# ID: 7781978, Name: Toshiba, RAM: 16GB, HD: 512GB SSD, Price: 1865
# ID: 9521144, Name: Microsoft, RAM: 8GB, HD: 256GB SSD, Price: 1867
# ID: 5766461, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1869
# ID: 9891483, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1869
# ID: 1782771, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1870
# ID: 7376742, Name: Asus, RAM: 8GB, HD: 512GB SSD, Price: 1873
# ID: 5313098, Name: Lenovo, RAM: 8GB, HD: 256GB Flash Storage, Price: 1875
# ID: 3755017, Name: Toshiba, RAM: 16GB, HD: 512GB SSD, Price: 1877
# ID: 4522578, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1887
# ID: 9157058, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1890
# ID: 9405399, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1891
# ID: 9849304, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1895
# ID: 6872646, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 1899
# ID: 7122247, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1899
# ID: 6893991, Name: Asus, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 1899
# ID: 2400857, Name: LG, RAM: 8GB, HD: 512GB SSD, Price: 1899
# ID: 9554063, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1899
# ID: 4788986, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 1899
# ID: 9016949, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1899
# ID: 3591694, Name: Asus, RAM: 16GB, HD: 512GB SSD, Price: 1900
# ID: 4875402, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 1900
# ID: 7818327, Name: Asus, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 1900
# ID: 4774174, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1903
# ID: 5943946, Name: HP, RAM: 8GB, HD: 500GB HDD, Price: 1907
# ID: 4539526, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1908
# ID: 6927432, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1925
# ID: 7829140, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1929
# ID: 7471698, Name: Acer, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 1935
# ID: 5250704, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1943
# ID: 9876055, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1948
# ID: 9695151, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1949
# ID: 8611276, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 1949
# ID: 1681649, Name: Asus, RAM: 16GB, HD: 512GB SSD, Price: 1950
# ID: 7070927, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 1950
# ID: 4132701, Name: Apple, RAM: 8GB, HD: 512GB SSD, Price: 1958
# ID: 7121038, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1962
# ID: 1019813, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 1962
# ID: 6008932, Name: HP, RAM: 16GB, HD: 512GB SSD, Price: 1965
# ID: 2239091, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1969
# ID: 8196153, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 1970
# ID: 5155438, Name: HP, RAM: 16GB, HD: 256GB SSD, Price: 1975
# ID: 8313277, Name: Dell, RAM: 16GB, HD: 256GB SSD, Price: 1975
# ID: 9571095, Name: Toshiba, RAM: 16GB, HD: 256GB SSD, Price: 1975
# ID: 2623571, Name: Asus, RAM: 16GB, HD: 512GB SSD, Price: 1983
# ID: 8162291, Name: Dell, RAM: 8GB, HD: 64GB Flash Storage +  1TB HDD, Price: 1993
# ID: 3043315, Name: HP, RAM: 12GB, HD: 256GB SSD +  1TB HDD, Price: 1999
# ID: 5638350, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 1999
# ID: 5978354, Name: Dell, RAM: 8GB, HD: 512GB SSD, Price: 2013
# ID: 2940728, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 2014
# ID: 9058977, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 2025
# ID: 2702455, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 2027
# ID: 4763919, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2029
# ID: 6965963, Name: Apple, RAM: 8GB, HD: 512GB SSD, Price: 2040
# ID: 2680831, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 2041
# ID: 8468788, Name: Dell, RAM: 8GB, HD: 1TB HDD, Price: 2046
# ID: 6683244, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2048
# ID: 3219163, Name: Lenovo, RAM: 8GB, HD: 256GB Flash Storage, Price: 2049
# ID: 2857045, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2049
# ID: 6670206, Name: HP, RAM: 16GB, HD: 512GB SSD, Price: 2049
# ID: 3106341, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 2050
# ID: 9224516, Name: Dell, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2051
# ID: 7791590, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2064
# ID: 2492585, Name: HP, RAM: 8GB, HD: 512GB SSD, Price: 2089
# ID: 5209898, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 2090
# ID: 7403225, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2094
# ID: 8888588, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2099
# ID: 3709054, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2099
# ID: 8134119, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2099
# ID: 9161923, Name: LG, RAM: 16GB, HD: 512GB SSD, Price: 2099
# ID: 2795362, Name: HP, RAM: 8GB, HD: 256GB SSD +  500GB HDD, Price: 2103
# ID: 5299157, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2122
# ID: 1217342, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 2135
# ID: 1450726, Name: Apple, RAM: 16GB, HD: 256GB Flash Storage, Price: 2139
# ID: 2732619, Name: Asus, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 2150
# ID: 5903313, Name: MSI, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2153
# ID: 2019403, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2171
# ID: 1050527, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2198
# ID: 2304858, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2199
# ID: 8360704, Name: Google, RAM: 16GB, HD: 512GB SSD, Price: 2199
# ID: 4309911, Name: MSI, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2199
# ID: 2816522, Name: Toshiba, RAM: 16GB, HD: 512GB SSD, Price: 2226
# ID: 3362314, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2229
# ID: 9084507, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2229
# ID: 9001734, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 2240
# ID: 1594643, Name: MSI, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 2241
# ID: 2455950, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2249
# ID: 5652697, Name: HP, RAM: 8GB, HD: 8GB SSD, Price: 2249
# ID: 3311285, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 2250
# ID: 8004533, Name: Dell, RAM: 16GB, HD: 1TB SSD, Price: 2254
# ID: 1223664, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2267
# ID: 2047558, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2277
# ID: 5091951, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 2282
# ID: 7945531, Name: Lenovo, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2289
# ID: 1116856, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2296
# ID: 3455213, Name: MSI, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 2299
# ID: 8226367, Name: LG, RAM: 8GB, HD: 512GB SSD, Price: 2299
# ID: 2548106, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2299
# ID: 9337913, Name: Acer, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2299
# ID: 4882525, Name: Asus, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2299
# ID: 9675105, Name: Lenovo, RAM: 12GB, HD: 512GB SSD, Price: 2299
# ID: 1749261, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2325
# ID: 2465384, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 2330
# ID: 4869811, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 2338
# ID: 3541816, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 2339
# ID: 8325347, Name: MSI, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2349
# ID: 6836410, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2350
# ID: 6031295, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2370
# ID: 9708898, Name: Lenovo, RAM: 24GB, HD: 512GB SSD, Price: 2382
# ID: 5390619, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 2397
# ID: 8681428, Name: Dell, RAM: 16GB, HD: 1TB SSD, Price: 2399
# ID: 9206819, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2399
# ID: 5942103, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 2408
# ID: 5674490, Name: MSI, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 2415
# ID: 5684110, Name: HP, RAM: 16GB, HD: 256GB SSD, Price: 2419
# ID: 2041797, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2419
# ID: 5084310, Name: Apple, RAM: 16GB, HD: 256GB SSD, Price: 2439
# ID: 2206910, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2440
# ID: 7586340, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2445
# ID: 9745038, Name: MSI, RAM: 16GB, HD: 256GB SSD +  2TB HDD, Price: 2449
# ID: 7490527, Name: HP, RAM: 16GB, HD: 1TB SSD, Price: 2449
# ID: 4377081, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2449
# ID: 2443012, Name: Asus, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2449
# ID: 3086218, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2450
# ID: 1725414, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2456
# ID: 9157769, Name: MSI, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 2499
# ID: 2417465, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2499
# ID: 7023626, Name: Dell, RAM: 16GB, HD: 1TB SSD, Price: 2499
# ID: 5455162, Name: Lenovo, RAM: 8GB, HD: 512GB SSD, Price: 2499
# ID: 8682254, Name: MSI, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2499
# ID: 2658016, Name: Dell, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 2505
# ID: 2262347, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2509
# ID: 9722156, Name: Apple, RAM: 16GB, HD: 512GB SSD, Price: 2537
# ID: 5149636, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 2559
# ID: 4525445, Name: Microsoft, RAM: 16GB, HD: 512GB SSD, Price: 2589
# ID: 9987866, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 2590
# ID: 8042226, Name: Razer, RAM: 16GB, HD: 256GB SSD, Price: 2599
# ID: 4659899, Name: Acer, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2599
# ID: 5690677, Name: Lenovo, RAM: 16GB, HD: 256GB SSD, Price: 2620
# ID: 1198983, Name: Lenovo, RAM: 16GB, HD: 1TB SSD, Price: 2625
# ID: 3706512, Name: Dell, RAM: 32GB, HD: 1TB SSD, Price: 2639
# ID: 9610781, Name: MSI, RAM: 16GB, HD: 512GB SSD +  2TB HDD, Price: 2649
# ID: 4793266, Name: Lenovo, RAM: 32GB, HD: 256GB SSD +  1TB HDD, Price: 2663
# ID: 6125403, Name: Dell, RAM: 16GB, HD: 512GB SSD, Price: 2680
# ID: 7521306, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2699
# ID: 9548081, Name: Dell, RAM: 8GB, HD: 256GB SSD, Price: 2712
# ID: 5665389, Name: MSI, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 2729
# ID: 3591230, Name: Lenovo, RAM: 16GB, HD: 256GB SSD +  1.0TB Hybrid, Price: 2749
# ID: 9736243, Name: Dell, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 2758
# ID: 7630759, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2774
# ID: 1380718, Name: MSI, RAM: 32GB, HD: 512GB SSD +  1TB HDD, Price: 2799
# ID: 3281537, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2799
# ID: 8872177, Name: Toshiba, RAM: 32GB, HD: 512GB SSD, Price: 2799
# ID: 2044920, Name: Asus, RAM: 32GB, HD: 512GB SSD, Price: 2799
# ID: 5687750, Name: Dell, RAM: 32GB, HD: 256GB SSD +  1TB HDD, Price: 2800
# ID: 8495640, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2813
# ID: 6693961, Name: Lenovo, RAM: 16GB, HD: 1TB SSD, Price: 2824
# ID: 8249973, Name: Apple, RAM: 16GB, HD: 512GB SSD, Price: 2858
# ID: 7483184, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 2868
# ID: 1289702, Name: Dell, RAM: 16GB, HD: 256GB SSD, Price: 2884
# ID: 7066959, Name: Razer, RAM: 16GB, HD: 512GB SSD, Price: 2899
# ID: 2938146, Name: HP, RAM: 8GB, HD: 1TB HDD, Price: 2899
# ID: 6105181, Name: Asus, RAM: 24GB, HD: 512GB SSD, Price: 2968
# ID: 8326459, Name: Lenovo, RAM: 16GB, HD: 512GB SSD, Price: 2968
# ID: 8106506, Name: Asus, RAM: 16GB, HD: 256GB SSD, Price: 2999
# ID: 2242324, Name: Lenovo, RAM: 8GB, HD: 256GB SSD, Price: 2999
# ID: 7749329, Name: Dell, RAM: 16GB, HD: 128GB SSD +  1TB HDD, Price: 3012
# ID: 3381880, Name: Dell, RAM: 16GB, HD: 256GB SSD +  1TB HDD, Price: 3055
# ID: 2288420, Name: Dell, RAM: 32GB, HD: 512GB SSD +  1TB HDD, Price: 3072
# ID: 1123169, Name: HP, RAM: 8GB, HD: 240GB SSD, Price: 3100
# ID: 2822622, Name: Dell, RAM: 32GB, HD: 512GB SSD +  1TB HDD, Price: 3147
# ID: 5323404, Name: Dell, RAM: 32GB, HD: 256GB SSD +  1TB HDD, Price: 3149
# ID: 9895567, Name: Dell, RAM: 16GB, HD: 512GB SSD +  1TB HDD, Price: 3154
# ID: 8148908, Name: Lenovo, RAM: 32GB, HD: 512GB SSD +  1.0TB Hybrid, Price: 3240
# ID: 4065168, Name: Lenovo, RAM: 16GB, HD: 1TB SSD, Price: 3299
# ID: 4061701, Name: Razer, RAM: 16GB, HD: 1TB SSD, Price: 3499
# ID: 9410993, Name: Dell, RAM: 32GB, HD: 1TB SSD +  1TB HDD, Price: 3588
# ID: 3570246, Name: Dell, RAM: 32GB, HD: 1TB SSD +  1TB HDD, Price: 3659
# ID: 6160702, Name: Asus, RAM: 32GB, HD: 512GB SSD +  1TB HDD, Price: 3890
# ID: 6611874, Name: HP, RAM: 8GB, HD: 256GB SSD, Price: 3949
# ID: 3335869, Name: Asus, RAM: 64GB, HD: 1TB SSD, Price: 3975
# ID: 3764268, Name: HP, RAM: 16GB, HD: 256GB SSD, Price: 4389
# ID: 5287124, Name: Lenovo, RAM: 32GB, HD: 1TB SSD, Price: 4899
# ID: 3319961, Name: Razer, RAM: 32GB, HD: 512GB SSD, Price: 5499
